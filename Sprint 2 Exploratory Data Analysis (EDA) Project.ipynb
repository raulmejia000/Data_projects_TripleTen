# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
# <b> Reviewer Rules</b>
#
# Hi there ;) I will be using the following color boxes through the notebook code:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Green means that it was nicely done.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Yellow color indicates what could be optimized. This is not necessary, but it will be great if you make changes to this project.
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Red is for things that must be done or changed for me to approve the project. If I rejected the project, you must look for this comments.
#
# </div>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Overall Summary**
#
# Dear Raul,
#
# Thank you for submitting your Exploratory Data Analysis (EDA) project on modified Instacart data. You have showcased a strong effort in data loading, cleaning, and exploration, using key Python libraries and data manipulation techniques. Below is a detailed review highlighting your project’s strengths and areas for improvement, with particular attention to mandatory requirements for project approval.
#
# ---
#
# <div style="border-left: 7px solid green; padding: 10px;">
# <b>✅ Strengths:</b>
# <ul>
#   <li><b>Data Import and Inspection:</b> Successfully loaded the Instacart datasets (orders, products, aisles, departments, and order_products) using the specified file paths, converting columns to appropriate data types for consistency.</li>
#   <li><b>Duplicate Detection and Handling:</b> Applied <code>duplicated()</code> and <code>drop_duplicates()</code> effectively to identify and remove redundant rows in multiple DataFrames, ensuring data integrity.</li>
#   <li><b>Missing Value Treatment:</b>
#     <ul>
#       <li><b>product_name:</b> Identified missing values and filled them with 'Unknown', justifying that these were associated with aisle_id 100 and department_id 21.</li>
#       <li><b>add_to_cart_order:</b> Imputed missing values with 999 and converted to integer type, preserving a uniform column data type.</li>
#       <li><b>days_since_prior_order:</b> Demonstrated awareness of missing values for first orders, though the approach to remove or impute was not exhaustively discussed.</li>
#     </ul>
#   </li>
#   <li><b>Completion of Mandatory Analysis Tasks:</b>
#     <ul>
#       <li><b>[A1 - A4]:</b> Verified <code>order_hour_of_day</code> and <code>order_dow</code> ranges; analyzed time-of-day and day-of-week shopping patterns; examined wait times between orders.</li>
#       <li><b>[B1 - B3]:</b> Compared order-hour distributions on Wednesdays and Saturdays, assessed orders-per-customer distribution, and identified top 20 popular products.</li>
#       <li><b>[C1 - C2]:</b> Explored how many items people typically buy in one order and determined top 20 frequently reordered products.</li>
#     </ul>
#   </li>
#   <li><b>Clear Code Organization:</b> Structured the notebook around the assignment’s tasks, using descriptive comments and logical code blocks to guide readers through the analysis steps.</li>
#   <li><b>Basic Visualizations:</b> Created histograms and bar plots to illustrate distributions of orders by hour, day of week, and item popularity, aiding quick interpretation of core findings.</li>
#   <li><b>Short, On-the-Spot Observations:</b> Included brief commentary after certain tasks, highlighting immediate insights (e.g., Sundays having the highest order volume, bananas dominating popular items).</li>
# </ul>
# </div>
#
# <div style="border-left: 7px solid gold; padding: 10px;">
# <b>⚠️ Areas for Improvement:</b>
# <ul>
#   <li><b>Dedicated Introduction:</b> The project starts with a code cell printing a short message about the Instacart EDA. While it provides a one-line context, it would be more effective to place a separate, more detailed markdown <em>Introduction</em> section clearly stating the project objectives, data sources, and the overall purpose of the analysis.</li>
#   <li><b>Unified Final Conclusion:</b> Multiple mini-conclusions appear throughout, but a single, <em>comprehensive Conclusion</em> summarizing all key insights at the end is missing. This is a mandatory requirement to tie together your findings.</li>
#   <li><b>In-depth Rationale for Data Removal:</b> While you acknowledged missing values in <code>days_since_prior_order</code> for first orders, providing a more explicit rationale (e.g., “We removed these rows because...”) would lend clarity. Alternatively, clarifying why you did not impute them can strengthen transparency.</li>
#   <li><b>Enhanced Chart Labelling and Readability:</b> Though your charts are functional, adding axis labels (especially for bar plots) and short descriptive titles can ensure they adhere to the requirement for clearly labeled, readable charts.</li>
#   <li><b>Extra Exploration:</b> Additional metrics, such as average order size by weekday or time of day, or deeper correlation analysis (e.g., using advanced visualizations) could provide more nuanced insights.</li>
# </ul>
# </div>
#
# <div style="border-left: 7px solid red; padding: 10px;">
# <b>⛔️ Critical Changes Required:</b>
# <ul>
#   <li><b>Add a Dedicated Introduction Section:</b>
#     <ul>
#       <li>Currently, the “introduction” is placed in a code cell as a single print statement. Convert or expand this into a <em>markdown cell</em> that briefly explains the objective and significance of the Instacart EDA project, the nature of the datasets, and any key questions you aim to address.</li>
#     </ul>
#   </li>
#   <li><b>Include an Overall Conclusion Section:</b>
#     <ul>
#       <li>A separate final conclusion is mandatory. Summarize all major findings (e.g., busiest day/hour, top products, reorder behaviors) and discuss how these insights might help stakeholders or inform next steps.</li>
#     </ul>
#   </li>
# </ul>
# </div>
#
# ---
#
# **Conclusion**
#
# Raul, you have made commendable progress in cleaning and exploring the Instacart dataset. You successfully addressed duplicate and missing values, completed mandatory analysis tasks, and offered concise observations of your results. However, to meet all project requirements and secure approval, you need to add a dedicated introduction (in a markdown cell) and conclude with a single overarching conclusion section integrating key findings from all tasks.
#
# **Next Steps**
#
# 1. **Insert a Detailed Introduction** in markdown format, outlining project objectives, data origin, and the importance of analyzing customer shopping habits.
# 2. **Add a Final Conclusion Section** at the end, synthesizing your major insights, such as busiest hours/days, item popularity, reorder patterns, and potential recommendations.
#
# Once these revisions are made, please resubmit your project for re-evaluation.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Overall Summary Iter 2**
#
# Approved :)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# It's good that you added an introduction using that print(), but it should be an independent markdown comment. You must create a new cell, change it from "code" to "markdown" and write there your introduction, middle comments, and conclusions. This will be mandatory on every project you do.
# </div>

# %% [markdown]
# Instacart Project: EDA
# This exploratory analysis of modified Instacart data uncovers customer shopping trends. By cleaning the dataset, handling missing and duplicate data, and visualizing key metrics, we provide insights into purchasing behaviors to enhance understanding of the platform’s dynamics.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment Iter 2 </b>
#
# Well done ;)
# </div>

# %%
import pandas as pd
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';', header=0)
instacart_orders = instacart_orders.astype({'order_id': 'int', 'user_id': 'int'})
print(instacart_orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None

# %%
products = pd.read_csv('/datasets/products.csv', sep=';', header=0)
products = products.astype({'product_id': 'int', 'aisle_id': 'int', 'department_id': 'int'})
print(products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None

# %%
aisles = pd.read_csv('/datasets/aisles.csv', sep=';', header=0)
aisles = aisles.astype({'aisle_id': 'int'})
print(aisles.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
departments = pd.read_csv('/datasets/departments.csv', sep=';', header=0)
departments = departments.astype({'department_id': 'int'})
print(departments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %%
order_products = pd.read_csv('/datasets/order_products.csv', sep=';', header=0)
order_products = order_products.astype({'order_id': 'int', 'product_id': 'int'})
print(order_products.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Great job :)
#
# </div>

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders.duplicated().sum())



# Check for duplicated orders
# Missing Values: could arise from various reasons such as incomplete data entry or errors during data collection
#Filling strategies depend on the data context; using 0, mean, median, or mode are common techniques.

# Duplicate Values: can result from data collection issues or merging datasets improperly.
# Removing duplicates ensures each record is unique and avoids skewing analysis.
# Out:
# 15

# %%
wednesday_2am_orders = instacart_orders[(instacart_orders['order_dow'] == 3) & (instacart_orders['order_hour_of_day'] == 2)]
print(wednesday_2am_orders.head())
# Check for all orders placed Wednesday at 2:00 AM
# Out:
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
# 18420                    11.0
# 24691                     9.0

# %%
instacart_orders = instacart_orders.drop_duplicates()
print(instacart_orders.duplicated().sum())
# Remove duplicate orders
# Out:
# 0

# %%
duplicate_rows = instacart_orders[instacart_orders.duplicated(keep=False)]

print(duplicate_rows)
# Double check for duplicate rows
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
duplicate_order_id = instacart_orders[instacart_orders['order_id'].duplicated(keep=False)]
duplicate_order_id
# Double check for duplicate order IDs only
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Good job
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
print(products.duplicated().sum())

# Check for duplicated orders
# Check for fully duplicate rows
# Out:
# 0

# %%
duplicates = products['product_id'].duplicated().sum()
print(f"Number of duplicate product IDs: {duplicates}")
# Check for just duplicate product IDs
# Out:
# Number of duplicate product IDs: 0

# %%
products[products['product_name'].str.lower().duplicated()]
# Check for just duplicate product names (convert names to lowercase to compare better)
# Out:
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 71                21
# ...

# %%
duplicates = products[products['product_name'].notna() & products['product_name'].str.lower().duplicated()]
print(duplicates)
# Check for duplicate product names that aren't missing
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  Biotin 1000 Mcg        47
# 5455         5456                 Green Tea With Ginseng and Honey        96
# 5558         5559                           Cream Of Mushroom Soup        69
# 7558         7559                        Cinnamon Rolls with Icing       105
# 9037         9038                           American Cheese slices        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# ### `departments` data frame

# %%
print(departments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %% [markdown]
# ### `aisles` data frame

# %%
print(aisles.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
aisles[aisles.duplicated(subset='aisle_id')]
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# ### `order_products` data frame

# %%
duplicate_rows = order_products[order_products.duplicated(keep = False)]
print(duplicate_rows)
# Check for fullly duplicate rows
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
tricky_duplicates = order_products[order_products.duplicated(subset=['order_id', 'add_to_cart_order', 'reordered'])]
print(tricky_duplicates)
# Double check for any other tricky duplicates
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 64336     1717990       39408                NaN          0
# 70057      264710       41602                NaN          0
# 128360    2449164       14386                NaN          0
# 137029    3347453       30727                NaN          0
# 147722     844733       22151                NaN          0
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [727 rows x 4 columns]

# %% [markdown]
# The dataset has no fully duplicate rows, but 727 partial duplicates based on key columns, possibly due to data entry or processing issues. These anomalies should be reviewed to ensure data accuracy and improve future analyses.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Any conclusions about this?
#
# </div>

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %%
products[(products['product_name'].isna()) & (products['aisle_id'] != 100)]
# Are all of the missing product names associated with aisle ID 100?
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
products[(products['product_name'].isna()) & (products['department_id'] != 21)]
# Are all of the missing product names associated with department ID 21?
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
aisle_name = aisles[aisles['aisle_id'] == 100]['aisle'].values[0]
department_name = departments[departments['department_id'] == 21]['department'].values[0]
print(f"Aisle: {aisle_name}")
print(f"Department: {department_name}")
# What is this ailse and department?
# Out:
# Aisle: missing
# Department: missing

# %%
products.loc[products['product_name'].isna(), 'product_name'] = 'Unknown'
# Fill missing product names with 'Unknown'

# %% [markdown]
# ### `orders` data frame

# %%
missing_values = instacart_orders[(instacart_orders['order_number'] != 1) & (instacart_orders.isna().any(axis=1))]
print(missing_values)
print(missing_values.head())
# Are there any missing values where it's not a customer's first order?
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ### `order_products` data frame

# %%
min_days_since_order = instacart_orders['days_since_prior_order'].min()
max_days_since_order = instacart_orders['days_since_prior_order'].max()
print(f"Min days_since_prior_order: {min_days_since_order}")
print(f"Max days_since_prior_order: {max_days_since_order}")
# What are the min and max values in this column?
# Out:
# Min days_since_prior_order: 0.0
# Max days_since_prior_order: 30.0

# %%
missing_add_to_cart = order_products[order_products['add_to_cart_order'].isna()]


order_ids_with_missing = missing_add_to_cart['order_id'].unique()

print(order_ids_with_missing)
# Save all order IDs with at least one missing value in 'add_to_cart_order'
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
orders_with_missing = order_products[order_products['add_to_cart_order'].isna()]

order_counts = orders_with_missing['order_id'].value_counts()

orders_over_64 = order_counts[order_counts > 64]
print(orders_over_64)
# Do all orders with missing values have more than 64 products?
# Out:
# Series([], Name: order_id, dtype: int64)

# %%
order_products['add_to_cart_order'].fillna(999, inplace=True)

order_products['add_to_cart_order'] = order_products['add_to_cart_order'].astype(int)

print(order_products.head())
# Replace missing values with 999 and convert column to integer type
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440                 17          0
# 1    567889        1560                  1          1
# 2   2261212       26683                  1          1
# 3    491251        8670                 35          1
# 4   2571142        1940                  5          1

# %% [markdown]
# To ensure data integrity and usability, we addressed missing and duplicate values across key datasets, laying a strong foundation for accurate analysis.
#
# In the Products dataset, missing product names linked to aisle and department IDs were filled with “Unknown” to maintain consistency and support product categorization. The Orders dataset had no missing values for non-first customer orders, ensuring completeness for analyzing repeat purchase behavior.
#
# For the Order_Products dataset, we verified that days since prior order ranged between 0 and 30, offering insights into customer purchase cycles for marketing and inventory planning. Missing add_to_cart_order values were handled with a placeholder (999) to retain data structure while flagging them for careful interpretation. Additionally, while no fully duplicate rows were found, 727 partial duplicates were identified, likely stemming from data entry or processing inconsistencies.
#
# By proactively handling these issues, we enhanced data reliability, enabling more precise customer behavior analysis, inventory management, and targeted marketing strategies.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment Iter 2 </b>
#
# Good job
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# You did good, but you must add a conclusion here, with detailed insights about what you did in this data preparation process.
#
# Please, with deep details in the comemnts you make. This will be asked for on every future project.
#
# </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
hour_min = instacart_orders['order_hour_of_day'].min()
hour_max = instacart_orders['order_hour_of_day'].max()
print(f"Order hour min: {hour_min}, max: {hour_max}")
# Check order_dow
# Out:
# Order hour min: 0, max: 23

# %%
dow_min = instacart_orders['order_dow'].min()
dow_max = instacart_orders['order_dow'].max()
print(f"Order day of week min: {dow_min}, max: {dow_max}")
# Out:
# Order day of week min: 0, max: 6

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Great job :)
#
# </div>

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
instacart_orders['order_hour_of_day'].hist(bins=24, color='skyblue', edgecolor='black')
plt.title('Distribution of Orders by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.grid(False)
plt.show()

# %% [markdown]
# The histogram reveals peak grocery orders occur from late morning to early afternoon, while early morning and late night see lower activity. These patterns can inform staffing, inventory management, and promotional strategies to optimize operations and enhance customer experience.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Good, but please, add a conclusion or some text. What do you get from this? Any insights?
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment Iter 2 </b>
#
# Correct
# </div>

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
order_dow_counts = instacart_orders['order_dow'].value_counts().sort_index()

plt.figure(figsize=(8, 6))
order_dow_counts.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Orders by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Orders')
plt.xticks(ticks=range(7), labels=['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat'])
plt.grid(False)
plt.show()
print(f"Sunday is the most popular day of the week for placing orders, meaning highest peak in shopping activities")
# Out:
# Sunday is the most popular day of the week for placing orders, meaning highest peak in shopping activities

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Great job :)
#
# </div>

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
plt.figure(figsize=(10, 6))
instacart_orders['days_since_prior_order'].hist(bins=30, color='lightcoral', edgecolor='black')
plt.title('Distribution of Days Since Prior Order')
plt.xlabel('Days Since Prior Order')
plt.ylabel('Number of Orders')
plt.grid(False)
plt.show()

# %%
print(f" 30 days is the max amount of time people wait before putting in their next order, As well as the highest volume of additonal orders occurs at the 30 day mark from the customers previous order")
# Out:
#  30 days is the max amount of time people wait before putting in their next order, As well as the highest volume of additonal orders occurs at the 30 day mark from the customers previous order

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Correct
# </div>

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
wednesdays = instacart_orders[instacart_orders['order_dow'] == 3]
saturdays = instacart_orders[instacart_orders['order_dow'] == 6]

plt.figure(figsize=(12, 6))
plt.hist(wednesdays['order_hour_of_day'], bins=24, alpha=0.5, label='Wednesday', color='blue', edgecolor='black')
plt.hist(saturdays['order_hour_of_day'], bins=24, alpha=0.5, label='Saturday', color='orange', edgecolor='black')
plt.title('Order Hour Distribution: Wednesday vs. Saturday')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Nice graph, what you conclude from this? Any insights?
#
# </div>

# %% [markdown]
# Both days follow similar shopping patterns, peaking in late morning to early afternoon. However, Saturdays see consistently higher order volumes, likely due to increased weekend shopping. This insight can help optimize staffing, inventory, and marketing strategies to manage demand and boost midweek sales.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment Iter 2 </b>
#
# I like it ;)
# </div>

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
orders_per_customer = instacart_orders.groupby('user_id')['order_id'].count()

plt.figure(figsize=(10, 6))
orders_per_customer.hist(bins=30, color='teal', edgecolor='black')
plt.title('Distribution of Number of Orders per Customer')
plt.xlabel('Number of Orders')
plt.ylabel('Number of Customers')
plt.grid(False)
plt.show()

# %%
print(f"The majority of customers place around five orders, indicating a common shopping frequency. Beyond five orders, the number of customers decreases noticeably, suggesting that less frequent, high-volume shopping is rare. This pattern suggests a tendency towards moderate repeat purchases within the customer base.")
# Out:
# The majority of customers place around five orders, indicating a common shopping frequency. Beyond five orders, the number of customers decreases noticeably, suggesting that less frequent, high-volume shopping is rare. This pattern suggests a tendency towards moderate repeat purchases within the customer base.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# I agree, well done
#
# </div>

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
df_merge = order_products.merge(products, on="product_id")
top_products = (df_merge.groupby(["product_id", "product_name"]).size().sort_values(ascending=False))
top_20_products = top_products.head(20)
top_20_products.plot.bar()
plt.show()

# %%
print(f"The analysis of item popularity reveals that bananas are the most frequently purchased item, underscoring their role as a grocery staple. Beyond bananas, the steady decline in popularity suggests diverse but less concentrated purchasing habits. The presence of fresh produce such as spinach, avocados, and strawberries in the top 20 items points to a trend toward health-conscious shopping. These insights can inform inventory management and strategic promotions to align with customer preferences.")
# Out:
# The analysis of item popularity reveals that bananas are the most frequently purchased item, underscoring their role as a grocery staple. Beyond bananas, the steady decline in popularity suggests diverse but less concentrated purchasing habits. The presence of fresh produce such as spinach, avocados, and strawberries in the top 20 items points to a trend toward health-conscious shopping. These insights can inform inventory management and strategic promotions to align with customer preferences.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Great job :)
#
# </div>

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
items_per_order = order_products.groupby('order_id').size()

plt.figure(figsize=(10, 6))
items_per_order.hist(bins=30, color='purple', edgecolor='black')
plt.title('Distribution of Items per Order')
plt.xlabel('Number of Items')
plt.ylabel('Number of Orders')
plt.grid(False)
plt.show()

# %%
print(f"The order size distribution indicates that most purchases are small to medium, with fewer than 10 items per order, reflecting routine shopping behavior. The right-skewed distribution suggests that while smaller orders are common, larger purchases are less frequent. A small number of orders exceed 30 items, likely representing occasional bulk-buying trips. These insights can inform inventory management and marketing strategies.")
# Out:
# The order size distribution indicates that most purchases are small to medium, with fewer than 10 items per order, reflecting routine shopping behavior. The right-skewed distribution suggests that while smaller orders are common, larger purchases are less frequent. A small number of orders exceed 30 items, likely representing occasional bulk-buying trips. These insights can inform inventory management and marketing strategies.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Correct
#
# </div>

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
top_reordered = order_products[order_products['reordered'] == 1]

# %%
top_reordered = top_reordered.groupby('product_id').size().nlargest(20)

# %%
top_reordered_info = products.merge(top_reordered.reset_index(), on='product_id')
print(top_reordered_info)
# Out:
#     product_id              product_name  aisle_id  department_id      0
# 0         5876             Organic Lemon        24              4   8412
# 1         8277  Apple Honeycrisp Organic        24              4   8836
# 2        13176    Bag of Organic Bananas        24              4  44450
# 3        16797              Strawberries        24              4  13945
# 4        21137      Organic Strawberries        24              4  28639
# 5        21903      Organic Baby Spinach       123              4  26233
# 6        22935      Organic Yellow Onion        83              4  11145
# 7        24852                    Banana        24              4  55763
# 8        24964            Organic Garlic        83              4  10411
# 9        26209                     Limes        24              4  13327
# 10       27845        Organic Whole Milk        84             16  16251
# 11       27966       Organic Raspberries       123              4  14748
# ...

# %%
print(f"An examination of the top 20 reordered items reveals that the leading five—Organic Lemon, Apple Honeycrisp Organic, Bag of Organic Bananas, Strawberries, and Organic Strawberries—are primarily organic and fresh produce. This trend suggests a strong customer preference for organic options and healthy food choices, emphasizing the importance of stocking these high-demand items to meet recurring shopping habits.")
# Out:
# An examination of the top 20 reordered items reveals that the leading five—Organic Lemon, Apple Honeycrisp Organic, Bag of Organic Bananas, Strawberries, and Organic Strawberries—are primarily organic and fresh produce. This trend suggests a strong customer preference for organic options and healthy food choices, emphasizing the importance of stocking these high-demand items to meet recurring shopping habits.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Good, try to use markdown instead of print() please :)
#
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %%
order_counts = order_products.groupby('product_id')['reordered'].agg(['sum', 'count'])

order_counts['reorder_proportion'] = order_counts['sum'] / order_counts['count']

reorder_info = products[['product_id', 'product_name']].merge(
    order_counts['reorder_proportion'].reset_index(), on='product_id'
)

print(reorder_info.head())
# Out:
#    product_id                                       product_name  \
# 0           1                         Chocolate Sandwich Cookies
# 1           2                                   All-Seasons Salt
# 2           3               Robust Golden Unsweetened Oolong Tea
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           7                     Pure Coconut Water With Orange
#
#    reorder_proportion
# 0            0.564286
# 1            0.000000
# 2            0.738095
# 3            0.510204
# 4            0.500000

# %%
print(f"Robust Golden Unsweetened Oolong Tea (73%) shows the highest loyalty, while Chocolate Sandwich Cookies (56%), Smart Ones Classic Favorites (51%), and Pure Coconut Water With Orange (50%) indicate steady demand. In contrast, All-Seasons Salt (0%) appears to be a one-time purchase. These trends highlight opportunities for inventory and marketing optimization.")
# Out:
# Robust Golden Unsweetened Oolong Tea (73%) shows the highest loyalty, while Chocolate Sandwich Cookies (56%), Smart Ones Classic Favorites (51%), and Pure Coconut Water With Orange (50%) indicate steady demand. In contrast, All-Seasons Salt (0%) appears to be a one-time purchase. These trends highlight opportunities for inventory and marketing optimization.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Good job, it's good that you are adding conclusions here
#
# </div>

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %%
merged_df = order_products.merge(instacart_orders[['order_id', 'user_id']], on='order_id')

total_orders_customer = merged_df.groupby('user_id').size()
reorders_customer = merged_df[merged_df['reordered'] == 1].groupby('user_id').size()

reorder_proportion_customer = (reorders_customer / total_orders_customer).fillna(0)

print(reorder_proportion_customer.head())
# Out:
# user_id
# 2    0.038462
# 4    0.000000
# 5    0.666667
# 6    0.000000
# 7    0.928571
# dtype: float64

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %% [markdown]
# first_cart_items = order_products[order_products['add_to_cart_order'] == 1]
#
# first_counts = first_cart_items['product_id'].value_counts()
#
# top_20_first = first_counts.head(20)
#
# top_20_first_info = products[['product_id', 'product_name']].merge(
#     top_20_first.reset_index(), on='product_id'
# )
#
# print(top_20_first_info)

# %%
print(f"The top 20 first-added items reveal key insights into product popularity, consumer preferences, and marketing opportunities. These products are highly prioritized, reflecting their essential nature. The diversity in categories suggests varied shopper needs, guiding inventory and marketing strategies. This insight can help target promotions or suggest complementary products to enhance sales.")
# Out:
# The top 20 first-added items reveal key insights into product popularity, consumer preferences, and marketing opportunities. These products are highly prioritized, reflecting their essential nature. The diversity in categories suggests varied shopper needs, guiding inventory and marketing strategies. This insight can help target promotions or suggest complementary products to enhance sales.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Good job overall :)
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# You must add a final conclusion here, summarizing all the insights you got.
#
# </div>

# %% [markdown]
# The analysis reveals key shopping patterns that can guide business decisions. Essential items like cheese and personal care products are frequently added to carts, highlighting priorities for inventory and marketing. Organic and fresh produce dominate reorders, reflecting a health-conscious trend and the need for consistent stock.
#
# Most customers place around five orders, favoring smaller, frequent purchases over bulk buying. Peak shopping times occur from late morning to early afternoon, with higher activity on weekends, emphasizing the importance of optimized staffing and promotions.
#
# Products like Robust Golden Unsweetened Oolong Tea show high reorder rates, signaling strong brand loyalty and opportunities for targeted marketing. Additionally, analyzing order distributions across days and customers helps refine sales and operational strategies.
#
# These insights support better inventory management, strategic marketing, and improved customer experiences, ultimately driving business success.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment Iter 2 </b>
#
# Good job Raul, thanks for the changes! Approved
# </div>
